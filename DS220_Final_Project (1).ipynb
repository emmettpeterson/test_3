# %%
# %%shell
# jupyter nbconvert --to html /content/DS220_Final_Project.ipynb

# %% [markdown]
# This Data was gathered from Kaggle.Com.

# %%
import pandas as pd
import matplotlib.pyplot as plt
data_batting=pd.read_csv("/content/SDP_batting.csv")
data_pitching=pd.read_csv("/content/SDP_pitching.csv")

# %% [markdown]
# Through the use of ".columns",".head()", and ".tail()" we can see the variables present in the data frame.  By looking at the column names, we are able to see that each individual row represents a single player's performance in a specific year.  Each row then shows the player's Name, Age, and then their hitting stats.

# %%
data_batting.columns
# Out:
# Index(['Rank', 'Year', 'Position', 'Name', 'Age', 'Games', 'Plate_Appearances',
#        'At_Bats', 'Runs', 'Hits', 'Doubles', 'Triples', 'Home_Runs',
#        'Runs_Batted_In', 'Stolen_Bases', 'Caught_Stealing', 'Base_On_Balls',
#        'Strikeouts', 'Batting_Average', 'On_Base_Percentage',
#        'Slugging_Percentage', 'On_Base_Plus_Slugging_Percentage',
#        'On_Base_Plus_Slugging_Percentage_Plus', 'Total_Bases',
#        'Double_Plays_Grounded_Into', 'Times_Hit_By_Pitch', 'Sacrifice_Hits',
#        'Sacrifice_Flies', 'Intentional_Bases_on_Balls', 'Dominant_Hand',
#        'Switch_Hitter'],
#       dtype='object')

# %%
data_batting.head()
# Out:
#    Rank  Year Position              Name  Age  Games  Plate_Appearances  \
# 0     1  2023        C      Gary Sánchez   30     72                260
# 1     2  2023       1B  Jake Cronenworth   29    127                522
# 2     3  2023       2B      Ha-Seong Kim   27    152                626
# 3     4  2023       SS   Xander Bogaerts   30    155                665
# 4     5  2023       3B     Manny Machado   30    138                601
#
#    At_Bats  Runs  Hits  ...  On_Base_Plus_Slugging_Percentage  \
# 0      234    33    51  ...                             0.792
# 1      458    54   105  ...                             0.689
# 2      538    84   140  ...                             0.749
# 3      596    83   170  ...                             0.790
# 4      543    75   140  ...                             0.782
#
#    On_Base_Plus_Slugging_Percentage_Plus  Total_Bases  \
# 0                                    116          117
# ...

# %%
data_batting.tail()
# Out:
#       Rank  Year Position          Name  Age  Games  Plate_Appearances  \
# 2426    38  1969        P  Leon Everitt   22      6                  4
# 2427    39  1969        P   Steve Arlin   23      4                  2
# 2428    40  1969        P     Al McBean   31      1                  2
# 2429    41  1969        P  Billy McCool   24     54                  1
# 2430    42  1969        P     Tom Dukes   26     13                  1
#
#       At_Bats  Runs  Hits  ...  On_Base_Plus_Slugging_Percentage  \
# 2426        3     0     0  ...                              0.25
# 2427        2     0     0  ...                              0.00
# 2428        2     0     1  ...                              1.00
# 2429        1     0     0  ...                              0.00
# 2430        1     0     0  ...                              0.00
#
#       On_Base_Plus_Slugging_Percentage_Plus  Total_Bases  \
# 2426                                    -23            0
# ...

# %% [markdown]
# Through the use of ".columns",".head()" and ".tail()" we can see the variables present in the data frame.  By looking at the column names, we are able to see that each individual row represents a single player's performance in a specific year.  Each row then shows the player's Name, Age, and then their hitting stats.

# %%
data_pitching.columns
# Out:
# Index(['Rank', 'Year', 'Position', 'Name', 'Age', 'Wins', 'Losses',
#        'Winning_Percentage', 'Earned_Run_Average', 'Games_Played',
#        'Games_Started', 'Games_Finished', 'Complete_Games', 'Shutouts',
#        'Saves', 'Innings_Pitched', 'Hits_Allowed', 'Runs_Allowed',
#        'Earned_Runs', 'Home_Runs_Allowed', 'Walks_Allowed',
#        'Intentional_Walks_Allowed', 'Strikeouts', 'Hit_By_Pitch', 'Balks',
#        'Wild_Pitches', 'Batters_Faced', 'Adjusted_Earned_Run_Average',
#        'Fielding_Independent_Pitching', 'Walks_Hits_Per_Inning_Pitched',
#        'Hits_Per_Nine_Innings', 'Home_Runs_Per_Nine_Innings',
#        'Walks_Per_Nine_Innings', 'Strikeouts_Per_Nine_Innings',
#        'Strikeout_Walk_Ratio', 'Dominant_Hand', 'Switch_Hitter'],
#       dtype='object')

# %%
data_pitching.head()
# Out:
#    Rank  Year Position           Name  Age  Wins  Losses  Winning_Percentage  \
# 0     1  2023       SP    Blake Snell   30    14       9               0.609
# 1     2  2023       SP      Seth Lugo   33     8       7               0.533
# 2     3  2023       SP     Yu Darvish   36     8      10               0.444
# 3     4  2023       SP  Michael Wacha   31    14       4               0.778
# 4     5  2023       SP   Joe Musgrove   30    10       3               0.769
#
#    Earned_Run_Average  Games_Played  ...  Adjusted_Earned_Run_Average  \
# 0                2.25            32  ...                          182
# 1                3.57            26  ...                          115
# 2                4.56            24  ...                           90
# 3                3.22            24  ...                          127
# 4                3.05            17  ...                          134
#
#    Fielding_Independent_Pitching  Walks_Hits_Per_Inning_Pitched  \
# ...

# %%
data_pitching.tail()
# Out:
#       Rank  Year Position          Name  Age  Wins  Losses  \
# 1184    13  1969      NaN    Dick Selma   25     2       2
# 1185    14  1969      NaN  Mike Corkins   23     1       3
# 1186    15  1969      NaN  Leon Everitt   22     0       1
# 1187    16  1969      NaN   Steve Arlin   23     0       1
# 1188    17  1969      NaN     Al McBean   31     0       1
#
#       Winning_Percentage  Earned_Run_Average  Games_Played  ...  \
# 1184                0.50                4.09             4  ...
# 1185                0.25                8.47             6  ...
# 1186                0.00                8.04             5  ...
# 1187                0.00                9.28             4  ...
# 1188                0.00                5.14             1  ...
#
#       Adjusted_Earned_Run_Average  Fielding_Independent_Pitching  \
# 1184                           88                           3.69
# 1185                           43                           4.69
# ...

# %% [markdown]
# By looking at the shape of the batting data data, we can see that a total of 2431 players have batted for the San Diego Padres.

# %%
data_batting.shape
# Out:
# (2431, 31)

# %% [markdown]
# By looking at the shape of the pitching data data, we can see that a total of 1189 players have pitched for the San Diego Padres.

# %%
data_pitching.shape
# Out:
# (1189, 37)
